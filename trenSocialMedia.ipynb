# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
# Set path ke ChromeDriver
service = Service('chromedriver-win64\chromedriver.exe')

# Inisialisasi browser
driver = webdriver.Chrome(service=service)

# 1. Buka halaman Instagram dan login
driver.get('https://www.instagram.com/accounts/login/')
time.sleep(3)  # Tunggu beberapa detik hingga halaman login termuat

# %%
# Login ke Instagram
username = driver.find_element(By.NAME, 'username')
password = driver.find_element(By.NAME, 'password')
username.send_keys('a.faauzan')
password.send_keys('akmalfauzan123')
password.send_keys(Keys.RETURN)

time.sleep(5)  # Tunggu beberapa detik hingga halaman termuat
print("Login berhasil")
# Out:
# Login berhasil

# %%
# Buka halaman postingan
driver.get('https://www.instagram.com/p/C-Aof4tzmhW/')
time.sleep(5)  # Tunggu beberapa detik hingga halaman termuat

# %%
# Fungsi untuk mensimulasikan scrolling ke bawah halaman
def scroll_to_load_comments(driver):
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        # Scroll ke bawah halaman
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)  # Tunggu beberapa detik untuk memuat komentar tambahan
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

# Scroll untuk memuat lebih banyak komentar
scroll_to_load_comments(driver)
print("Scrolling selesai")

# Ambil komentar menggunakan XPath yang disalin
comments_elements = driver.find_elements(By.XPATH, '//*[@id="mount_0_0_Sv"]/div/div/div[2]/div/div/div[1]/div[1]/div[1]/section/main/div/div[1]/div/div[2]/div/div[2]')

comments = []
for comment in comments_elements:
    comments.append(comment.text)
    print(comment.text)  # Cetak komentar untuk verifikasi

# Simpan komentar ke dalam file
with open('comments.txt', 'w', encoding='utf-8') as f:
    for comment in comments:
        f.write(comment + '\n')

print("Comments saved to comments.txt")

# Tutup browser
driver.quit()
# Out:
# Scrolling selesai
# folkative
#  3h
# WE ARE THE CHAMPION 🥇🥇🥇🏅🏅🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩🇮🇩😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭
# irfanabluu
#  3h
# Raven, 100 panggilan tak terjawab dari Coach STY
# 8,622 likes
# Reply
# View all 81 replies
# satrialtfi
#  3h
# Bung rendra : " AYOOO KAKA!!! PAKSA KAKA!!! LARI KAKA!!!
# 2,997 likes
# Reply
# View all 15 replies
# dimaasaswad
#  3h
# Timnas: "Sudah saatnya pindah benua"
# 3,605 likes
# Reply
# See translation
# View all 19 replies
# putrioktavioni
#  3h
# "LARI KAKA" 😭😭
# 9,210 likes
# Reply
# View all 217 replies
# renndysptr
#  3h
# Jirayut bingung senang apa sedih
# 2,007 likes
# Reply
# See translation
# View all 14 replies
# meyzstr_
#  3h
# Degdegan campur ngakak denger komentator gregetan sama kaka 😭
# 797 likes
# Reply
# See translation
# View all 7 replies
# ryowesleyy
#  3h
# Tombol bangga banget —->
# 2,905 likes
# Reply
# View all 3 replies
# nandngbgus_
#  3h
# yang paling panik bukan pemain tapi komentator "LARI KAKA"😂🔥
# ...

# %%
# Baca komentar dari file
with open('comments.txt', 'r', encoding='utf-8') as f:
    comments = f.readlines()

# Bersihkan komentar (misalnya, hapus whitespace)
comments = [comment.strip() for comment in comments if comment.strip()]

# Buat DataFrame
komentar = pd.DataFrame(comments, columns=['Comment'])

# %%
komentar.shape
# Out:
# (103, 1)

# %%
komentar.sample(12)
# Out:
#                                  Comment
# 7                                  Reply
# 41                    View all 7 replies
# 40                       See translation
# 99                             101 likes
# 44              Tombol bangga banget —->
# 73                                 Reply
# 49                                    3h
# 19                                 Reply
# 97                                    3h
# 88                       See translation
# 17  Timnas: "Sudah saatnya pindah benua"
# 14                   View all 15 replies
